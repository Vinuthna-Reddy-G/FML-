# %% [markdown]
# <a href="https://colab.research.google.com/github/Vinuthna-Reddy-G/FML-/blob/main/Multivariate_train_test_split_startup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn import linear_model

# %% [markdown]
# Loading the data

# %%
data = pd.read_csv("50_Startups.csv")
data.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %% [markdown]
# Converting categorical data column (State) to numerical

# %%
data1 = pd.get_dummies(data['State'])
data = pd.concat([data, data1], axis=1).reindex(data.index)
data.drop('State', axis=1, inplace=True)
data.head()
# Out:
#    R&D Spend  Administration  Marketing Spend     Profit  California  Florida  \
# 0  165349.20       136897.80        471784.10  192261.83           0        0
# 1  162597.70       151377.59        443898.53  191792.06           1        0
# 2  153441.51       101145.55        407934.54  191050.39           0        1
# 3  144372.41       118671.85        383199.62  182901.99           0        0
# 4  142107.34        91391.77        366168.42  166187.94           0        1
#
#    New York
# 0         1
# 1         0
# 2         0
# 3         1
# 4         0

# %% [markdown]
# Creation of features and target from the given data

# %%
X = data.drop('Profit', axis=1).values
y = data['Profit'].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05, random_state=4)

# %%
X_train.shape, X_test.shape
# Out:
# ((47, 6), (3, 6))

# %% [markdown]
# Fitting a regression model

# %%
reg = linear_model.LinearRegression()
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Evaluation of the model on training data only

# %%
from sklearn.metrics import mean_absolute_error,r2_score,mean_squared_error
y_pred1 = reg.predict(X_train)
print(f'Performance of the model on training data :\n')
print(f'MAE = {mean_absolute_error(y_train, y_pred1)}')
print(f'MSE = {mean_squared_error(y_train, y_pred1)}')
print(f'RMSE = {np.sqrt(mean_squared_error(y_train, y_pred1))}')
print(f'R_2 = {r2_score(y_train, y_pred1)}')
# Out:
# Performance of the model on training data :
#
# MAE = 6446.993093070803
# MSE = 76689820.54472193
# RMSE = 8757.272437507123
# R_2 = 0.9490840559696544

# %% [markdown]
# Evaluation of the model on testing data only

# %%
from sklearn.metrics import mean_absolute_error,r2_score,mean_squared_error
y_pred2 = reg.predict(X_test)
print(f'Performance of the model on test data :\n')
print(f'MAE = {mean_absolute_error(y_test, y_pred2)}')
print(f'MSE = {mean_squared_error(y_test, y_pred2)}')
print(f'RMSE = {np.sqrt(mean_squared_error(y_test, y_pred2))}')
print(f'R_2 = {r2_score(y_test, y_pred2)}')
# Out:
# Performance of the model on test data :
#
# MAE = 9225.270272259868
# MSE = 129407701.51294868
# RMSE = 11375.750591189519
# R_2 = 0.9559498738686317
